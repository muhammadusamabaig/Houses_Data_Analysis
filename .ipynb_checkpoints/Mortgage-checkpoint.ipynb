# %%
import pandas as pd
import numpy as np

# %%
df_product = pd.read_excel(r'product.xlsx')

# %%
df_customer=pd.read_excel(r'customer.xlsx')

# %%
df_product.columns=['ID','Building','Year of sale','Month of sale','Type of property','property','Area','Price','Status']

# %%
df_product.dtypes
# Out:
# ID                    int64
# Building              int64
# Year of sale        float64
# Month of sale       float64
# Type of property     object
# property              int64
# Area                float64
# Price               float64
# Status               object
# dtype: object

# %%
df_product
# Out:
#        ID  Building  Year of sale  Month of sale Type of property  property  \
# 0    1030         1        2005.0           11.0        Apartment        30
# 1    1029         1        2005.0           10.0        Apartment        29
# 2    2002         2        2007.0            7.0        Apartment         2
# 3    2031         2        2007.0           12.0        Apartment        31
# 4    1049         1        2004.0           11.0        Apartment        49
# ..    ...       ...           ...            ...              ...       ...
# 262  5044         5           NaN            NaN        Apartment        44
# 263  5047         5           NaN            NaN        Apartment        47
# 264  5048         5           NaN            NaN        Apartment        48
# 265  5050         5           NaN            NaN        Apartment        50
# 266  5051         5           NaN            NaN        Apartment        51
#
#           Area        Price Status
# 0     743.0856  246172.6760   Sold
# 1     756.2128  246331.9040   Sold
# 2     587.2808  209280.9104   Sold
# 3    1604.7464  452667.0064   Sold
# 4    1375.4508  467083.3132   Sold
# ..         ...          ...    ...
# 262  1238.5836  322610.7392    NaN
# 263   794.5184  279191.2560    NaN
# 264  1013.2692  287996.5296    NaN
# 265  1074.7088  365868.7776    NaN
# 266   789.2460  199216.4040    NaN
#
# [267 rows x 9 columns]

# %%
df_customer.dtypes
# Out:
# Unnamed: 0                 float64
# ID                          object
# Entity                      object
# Name                        object
# Surname                     object
# Age at time of purchase    float64
# Interval                   float64
# Y                          float64
# M                          float64
# D                          float64
# Gender                      object
# Country                     object
# State                       object
# Purpose                     object
# Deal satisfaction          float64
# Mortgage                    object
# Source                      object
# dtype: object

# %%
df_customer.drop('Unnamed: 0',axis=1)
# Out:
#         ID      Entity        Name   Surname  Age at time of purchase  \
# 0    C0028  Individual     Madalyn    Mercer                      NaN
# 1    C0027  Individual        Lara  Carrillo                      NaN
# 2    C0112  Individual     Donavan   Flowers                      NaN
# 3    C0160  Individual      Darien    Dorsey                      NaN
# 4    C0014  Individual  Alessandra     Perry                      NaN
# ..     ...         ...         ...       ...                      ...
# 191  C0174        Firm     Marleez        Co                      NaN
# 192  C0174        Firm     Marleez        Co                      NaN
# 193  C0174        Firm     Marleez        Co                      NaN
# 194  C0174        Firm     Marleez        Co                      NaN
# 195  C0174        Firm     Marleez        Co                      NaN
#
#      Interval       Y     M     D Gender Country       State     Purpose  \
# 0         NaN  1986.0   6.0  21.0      F     USA  California        Home
# 1         NaN  1983.0   2.0  24.0      F     USA  California        Home
# 2         NaN  1985.0  12.0  27.0      M     USA  California        Home
# 3         NaN  1985.0  12.0  27.0      M     USA  California  Investment
# 4         NaN  1979.0   5.0  15.0      F     USA  California        Home
# ..        ...     ...   ...   ...    ...     ...         ...         ...
# 191       NaN     NaN   NaN   NaN    NaN     USA  California  Investment
# 192       NaN     NaN   NaN   NaN    NaN     USA  California  Investment
# 193       NaN     NaN   NaN   NaN    NaN     USA  California  Investment
# 194       NaN     NaN   NaN   NaN    NaN     USA  California  Investment
# 195       NaN     NaN   NaN   NaN    NaN     USA  California  Investment
#
#      Deal satisfaction Mortgage   Source
# 0                  5.0       No  Website
# 1                  5.0       No  Website
# 2                  1.0      Yes   Client
# 3                  3.0      Yes  Website
# 4                  4.0       No   Agency
# ..                 ...      ...      ...
# 191                5.0       No  Website
# 192                5.0       No  Website
# 193                5.0       No  Website
# 194                5.0       No  Website
# 195                5.0       No  Website
#
# [196 rows x 16 columns]

# %%
NO,YES=(df_customer['Mortgage'].value_counts()/df_customer['Mortgage'].count())*100
# df_customer['Mortgage'].count()
# df_customer['Mortgage'].count()
(df_customer['Mortgage'].value_counts()/df_customer['Mortgage'].count())*100
# Out:
# No     68.717949
# Yes    31.282051
# Name: Mortgage, dtype: float64

# %%
# Yes/df_customer['Mortgage'].count()*100
# No=No/df_customer['Mortgage'].count()*100

# %%
df = pd.DataFrame({'MORTGAGE': [NO,YES]},
                  index=['No', 'YES'])
plot = df.plot.pie(y='MORTGAGE', figsize=(8, 8))
